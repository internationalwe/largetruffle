# %%
#importing libraries and dataset
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df11 = pd.read_csv('C:\\Users\\user\\Desktop\\data11.csv')
df11.head()
# Out:
#   Unnamed: 0  1개 -25개  26개-50개  51개-80개  80개 이상
# 0      가스레인지        2        0        0       0
# 1       개수대류        8        0        0       0
# 2        고무통        3        0        0       0
# 3       골프가방        5        0        0       0
# 4         난로        3        0        0       0

# %%
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

sns.catplot(data=df11)

# %%
df12 = pd.read_csv('C:\\Users\\user\\Desktop\\data12.csv')
df12.head()
# Out:
#   Unnamed: 0  1개 -25개  26개-50개  51개-80개  80개 이상
# 0      가스레인지      2.0      NaN      NaN     NaN
# 1       개수대류      8.0      NaN      NaN     NaN
# 2        고무통      3.0      NaN      NaN     NaN
# 3       골프가방      5.0      NaN      NaN     NaN
# 4         난로      3.0      NaN      NaN     NaN

# %%
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

 

#막대그래프
sns.catplot(data=df12)

plt.show()

# %%
plt.figure(figsize = (15 , 7))
sns.catplot(kind="box", data=df12)
plt.show()

# %%
sns.catplot(kind="violin", data=df12)

# %%
#폰트설정
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)



plt.figure(figsize = (15 , 7))
 
plt.title('< 카테고리별 분포 >' ,fontsize = 20)

sns.countplot(data = df12 ,  
              palette = 'Greens')

plt.xlabel('갯수' , fontsize = 15)


plt.xticks(rotation = 0)

plt.show()

# %%
plt.figure(figsize = (15 , 8))

plt.title('Review Kernel Density plot' , fontsize = 20)

sns.kdeplot(data = df12 ,
            fill = True , 
            alpha = 0.5)

plt.xlabel('Reviews' , fontsize = 15)
plt.ylabel('Density' , fontsize = 15)


plt.show()

# %%
#폰트설정
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)


3
plt.figure(figsize = (15 , 7))
 
plt.title('< 카테고리별 분포 >' ,fontsize = 20)

sns.countplot(data = df12 ,  
              palette = 'Greens')

plt.xlabel('갯수' , fontsize = 15)


plt.xticks(rotation = -45)

plt.show()

# %%
df14 = pd.read_csv('C:\\Users\\user\\Desktop\\data14.csv')
df14.head()
# Out:
#     카테고리  개수
# 0  가스레인지   2
# 1   개수대류   8
# 2    고무통   3
# 3   골프가방   5
# 4     난로   3

# %%
#폰트설정
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)


 
plt.title('< 카테고리별 분포 >' ,fontsize = 20)

sns.countplot(data = df14 ,  
              palette = 'Greens')

plt.xlabel('갯수' , fontsize = 15)


plt.xticks(rotation = -45)

plt.show()

# %%
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

plt.figure(figsize = (15 , 15))

sns.catplot(data=df14, color = 'green')
